# %%
# %matplotlib inline

import moabb
from moabb.datasets import BNCI2014001, Weibo2014, Zhou2016
from moabb.paradigms import LeftRightImagery
from moabb.evaluations import WithinSessionEvaluation

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.pipeline import make_pipeline

from mne.decoding import CSP

import matplotlib.pyplot as plt
import seaborn as sns

moabb.set_log_level('info')
import warnings
warnings.filterwarnings("ignore")

import mne
mne.set_log_level("CRITICAL")

# %%
datasets = [Zhou2016(), BNCI2014001(), Weibo2014()]

paradigm = LeftRightImagery()

evaluation = WithinSessionEvaluation(paradigm=paradigm, datasets=datasets, overwrite=True)

pipeline = make_pipeline(CSP(n_components=8), LDA())

results = evaluation.process({'csp+lda':pipeline})
# Out:
# 2019-08-22 14:32:22 desktop-270 root[18580] INFO Processing dataset: Zhou 2016
# 2019-08-22 14:32:28 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 1 | session_0: Score 0.883
# 2019-08-22 14:32:29 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 1 | session_1: Score 0.902
# 2019-08-22 14:32:29 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 1 | session_2: Score 0.948
# 2019-08-22 14:32:33 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 2 | session_0: Score 0.846
# 2019-08-22 14:32:34 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 2 | session_1: Score 0.765
# 2019-08-22 14:32:34 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 2 | session_2: Score 0.914
# 2019-08-22 14:32:39 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 3 | session_0: Score 0.952
# 2019-08-22 14:32:39 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 3 | session_1: Score 0.968
# 2019-08-22 14:32:40 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 3 | session_2: Score 0.990
# 2019-08-22 14:32:44 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 4 | session_0: Score 0.953
# 2019-08-22 14:32:44 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 4 | session_1: Score 0.988
# 2019-08-22 14:32:45 desktop-270 root[18580] INFO csp+lda | Zhou 2016 | 4 | session_2: Score 0.956
# 2019-08-22 14:32:45 desktop-270 root[18580] INFO Processing dataset: 001-2014

# %%
results
# Out:
#        score      time  samples subject    session  channels  n_sessions  \
# 0   0.929324  0.207828    144.0       1  session_E        22           2
# 1   0.923628  0.115765    144.0       1  session_T        22           2
# 2   0.683950  0.119550    144.0       2  session_E        22           2
# 3   0.670744  0.111850    144.0       2  session_T        22           2
# 4   0.995918  0.125966    144.0       3  session_E        22           2
# 5   0.998222  0.112972    144.0       3  session_T        22           2
# 6   0.832644  0.116260    144.0       4  session_E        22           2
# 7   0.795741  0.105265    144.0       4  session_T        22           2
# 8   0.601361  0.114891    144.0       5  session_E        22           2
# 9   0.575846  0.106382    144.0       5  session_T        22           2
# 10  0.782476  0.112921    144.0       6  session_E        22           2
# 11  0.758154  0.103490    144.0       6  session_T        22           2
# 12  0.965832  0.108887    144.0       7  session_E        22           2
# 13  0.849397  0.109362    144.0       7  session_T        22           2
# 14  0.994141  0.109320    144.0       8  session_E        22           2
# 15  0.998222  0.101650    144.0       8  session_T        22           2
# 16  0.969451  0.110274    144.0       9  session_E        22           2
# 17  0.856181  0.104797    144.0       9  session_T        22           2
# 18  0.771094  0.232993    160.0       1  session_0        60           1
# 19  0.953125  0.217639    160.0       2  session_0        60           1
# 20  0.485156  0.223623    160.0       3  session_0        60           1
# 21  0.568750  0.217868    160.0       4  session_0        60           1
# 22  0.788281  0.215810    160.0       5  session_0        60           1
# 23  0.985714  0.203210    140.0       6  session_0        60           1
# 24  0.960156  0.234953    160.0       7  session_0        60           1
# 25  0.993750  0.223874    160.0       8  session_0        60           1
# 26  0.857031  0.224901    160.0       9  session_0        60           1
# 27  0.679688  0.223384    160.0      10  session_0        60           1
# 28  0.849242  0.085287    119.0       1  session_0        16           3
# 29  0.912000  0.073317    100.0       1  session_1        16           3
# 30  0.980000  0.074124    100.0       1  session_2        16           3
# 31  0.844000  0.072762    100.0       2  session_0        16           3
# 32  0.765432  0.068508     90.0       2  session_1        16           3
# 33  0.876000  0.070770    100.0       2  session_2        16           3
# 34  0.986000  0.070378    100.0       3  session_0        16           3
# 35  0.970000  0.071267    100.0       3  session_1        16           3
# 36  0.996000  0.070971    100.0       3  session_2        16           3
# 37  0.967901  0.068453     90.0       4  session_0        16           3
# 38  0.996000  0.073260    100.0       4  session_1        16           3
# 39  0.952000  0.070135    100.0       4  session_2        16           3
#
#        dataset pipeline
# 0     001-2014  csp+lda
# 1     001-2014  csp+lda
# 2     001-2014  csp+lda
# 3     001-2014  csp+lda
# 4     001-2014  csp+lda
# 5     001-2014  csp+lda
# 6     001-2014  csp+lda
# 7     001-2014  csp+lda
# 8     001-2014  csp+lda
# 9     001-2014  csp+lda
# 10    001-2014  csp+lda
# 11    001-2014  csp+lda
# 12    001-2014  csp+lda
# 13    001-2014  csp+lda
# 14    001-2014  csp+lda
# 15    001-2014  csp+lda
# 16    001-2014  csp+lda
# 17    001-2014  csp+lda
# 18  Weibo 2014  csp+lda
# 19  Weibo 2014  csp+lda
# 20  Weibo 2014  csp+lda
# 21  Weibo 2014  csp+lda
# 22  Weibo 2014  csp+lda
# 23  Weibo 2014  csp+lda
# 24  Weibo 2014  csp+lda
# 25  Weibo 2014  csp+lda
# 26  Weibo 2014  csp+lda
# 27  Weibo 2014  csp+lda
# 28   Zhou 2016  csp+lda
# 29   Zhou 2016  csp+lda
# 30   Zhou 2016  csp+lda
# 31   Zhou 2016  csp+lda
# 32   Zhou 2016  csp+lda
# 33   Zhou 2016  csp+lda
# 34   Zhou 2016  csp+lda
# 35   Zhou 2016  csp+lda
# 36   Zhou 2016  csp+lda
# 37   Zhou 2016  csp+lda
# 38   Zhou 2016  csp+lda
# 39   Zhou 2016  csp+lda

# %%
results["subj"] = [str(resi).zfill(2) for resi in results["subject"]]
g = sns.catplot(kind='bar', x="score", y="subj", col="dataset", data=results, orient='h', palette='viridis')

# %%
import mne

# %%
help(mne.set_log_level)
# Out:
# Help on function set_log_level in module mne.utils:
#
# set_log_level(verbose=None, return_old_level=False)
#     Set the logging level.
#
#     Parameters
#     ----------
#     verbose : bool, str, int, or None
#         The verbosity of messages to print. If a str, it can be either DEBUG,
#         INFO, WARNING, ERROR, or CRITICAL. Note that these are for
#         convenience and are equivalent to passing in logging.DEBUG, etc.
#         For bool, True is the same as 'INFO', False is the same as 'WARNING'.
#         If None, the environment variable MNE_LOGGING_LEVEL is read, and if
#         it doesn't exist, defaults to INFO.
#     return_old_level : bool
#         If True, return the old verbosity level.
