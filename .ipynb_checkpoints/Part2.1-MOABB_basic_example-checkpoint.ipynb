# %% [markdown]
# # Making things simpler with MOABB (Part 1)
#
# In this notebook, we use the MOABB package for performing the same sequence of steps done on the previous notebook but with much less lines of code.
#
# ![architecture.png](attachment:architecture.png)

# %% [markdown]
# The first thing that we do is importing the required packages. This includes the packages for classification (`pyriemann` and `scikit-learn`), plotting (`matplotlib`) and MOABB itself.

# %%
# %matplotlib inline

import moabb
from moabb.datasets import BNCI2014001
from moabb.paradigms import LeftRightImagery
from moabb.evaluations import WithinSessionEvaluation

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.pipeline import make_pipeline

from mne.decoding import CSP

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

moabb.set_log_level('info')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Choosing a dataset

# %% [markdown]
# The first thing to do is instantiating the **dataset** that we want to analyse. MOABB has a list of many different datasets, each one containing all the necessary information for describing them, such as number of subjects, size of trials, names of classes, etc., etc.
#
# The *dataset* class has methods for:
# - downloading its files from some online source (e.g. Zenodo)
# - importing the data from the files in whatever extension they might be (like .mat, .gdf, etc.) and instantiate a Raw object from the MNE package

# %%
dataset = BNCI2014001()

# %% [markdown]
# As an example, we may access the EEG recording from a given session and a given run as follows:

# %%
sessions = dataset._get_single_subject_data(subject=1)
session_name = 'session_T'
run_name = 'run_1'
raw = sessions[session_name][run_name]

# %% [markdown]
# This returns a MNE Raw object that can be manipulated exactly as done in Part 1.1. For some people, this might be enough, since the pre-processing and epoching steps can be easily done via MNE. However, when assessing the score of a given set of classifiers on a loop of several subjects, MOABB ends up being a more appropriate option, as we will see next.

# %% [markdown]
# ### Choosing a paradigm

# %% [markdown]
# Once we instantiate a dataset, we have to choose a **paradigm**. This object is responsable for filtering the data, epoching it, and extracting the labels for each epoch. Note that each dataset comes with the names of the paradigms to which it might be associated -- It wouldn't make sense to process a P300 dataset with a MI paradigm object.

# %%
print(dataset.paradigm)
# Out:
# imagery

# %% [markdown]
# For the example that follows, we will consider the paradigm associated to left-hand/right-hand tasks, but there are other options in MOABB as well.

# %%
paradigm = LeftRightImagery()

# %% [markdown]
# We may check the list of all datasets available in MOABB for using with this paradigm (note that BNCI2014001 is in it)

# %%
paradigm.datasets
# Out:
# [<moabb.datasets.bnci.BNCI2014001 at 0x105f934e0>,
#  <moabb.datasets.bnci.BNCI2014004 at 0x105f935c0>,
#  <moabb.datasets.gigadb.Cho2017 at 0x105f93390>,
#  <moabb.datasets.mpi_mi.MunichMI at 0x105f936a0>,
#  <moabb.datasets.physionet_mi.PhysionetMI at 0x105f93550>,
#  <moabb.datasets.schirrmeister2017.Schirrmeister2017 at 0x105f935f8>,
#  <moabb.datasets.bbci_eeg_fnirs.Shin2017A at 0x105f93668>,
#  <moabb.datasets.Weibo2014.Weibo2014 at 0x105f93588>,
#  <moabb.datasets.Zhou2016.Zhou2016 at 0x105f93630>]

# %% [markdown]
# With the *paradigm* object, we may extract all the epochs and labels from the dataset very easily. The size of such epochs (that is, the $t_{\text{min}}$ and $t_{\text{max}}$) are specific to each dataset but may also be fixed as a parameters when instantiating the *paradigm* object.

# %%
X, labels, meta = paradigm.get_data(dataset=dataset, subjects=[1])

# %% [markdown]
# Note how simple this is as compared to the Notebook 1.1, where the trials were extracted using much more lines.

# %% [markdown]
# The *meta* object gives information about each extracted trial, specifying to which subject it belongs to, as well as to which recording session and running number it is associated.

# %% [markdown]
# ### Evaluating classification scores

# %% [markdown]
# Our goal is to evaluate the performance of a given classification pipeline (or several of them) when it is applied to the epochs from the dataset chosen previously. We will consider a very simple classification pipeline in which the epochs are dimension reduced via a CSP step and then classified via linear discriminant analysis.

# %%
pipeline = make_pipeline(CSP(n_components=8), LDA())

# %% [markdown]
# To evaluate the score of this pipeline, we use the *evaluation* class. When instantiating it, we say which paradigm we want to consider, a list with the datasets to analyse, and whether the scores should be recalculated each time we run the evaluation or if MOABB should create a cache file.
#
# Note that there are different ways of evaluating a classifier; in this example, we choose `WithinSessionEvaluation`, which consists of doing a cross-validation procedure where the training and testing partitions are from the same recording session of the dataset. We could have used `BetweenSessionEvaluation`, which takes one session as training partition and another one as testing partition.

# %%
evaluation = WithinSessionEvaluation(paradigm=paradigm, datasets=[dataset], overwrite=True)

# %% [markdown]
# We obtain the results in the form of a `pandas` dataframe

# %%
results = evaluation.process({'csp+lda':pipeline})
# Out:
# 2019-09-04 10:27:16 desktop-270 root[1026] INFO Processing dataset: 001-2014
# 2019-09-04 10:27:26 desktop-270 root[1026] INFO csp+lda | 001-2014 | 1 | session_E: Score 0.932
# 2019-09-04 10:27:26 desktop-270 root[1026] INFO csp+lda | 001-2014 | 1 | session_T: Score 0.929
# 2019-09-04 10:27:34 desktop-270 root[1026] INFO csp+lda | 001-2014 | 2 | session_E: Score 0.685
# 2019-09-04 10:27:34 desktop-270 root[1026] INFO csp+lda | 001-2014 | 2 | session_T: Score 0.632
# 2019-09-04 10:27:41 desktop-270 root[1026] INFO csp+lda | 001-2014 | 3 | session_E: Score 0.996
# 2019-09-04 10:27:42 desktop-270 root[1026] INFO csp+lda | 001-2014 | 3 | session_T: Score 0.992
# 2019-09-04 10:27:49 desktop-270 root[1026] INFO csp+lda | 001-2014 | 4 | session_E: Score 0.863
# 2019-09-04 10:27:49 desktop-270 root[1026] INFO csp+lda | 001-2014 | 4 | session_T: Score 0.829
# 2019-09-04 10:27:56 desktop-270 root[1026] INFO csp+lda | 001-2014 | 5 | session_E: Score 0.567
# 2019-09-04 10:27:57 desktop-270 root[1026] INFO csp+lda | 001-2014 | 5 | session_T: Score 0.558
# 2019-09-04 10:28:04 desktop-270 root[1026] INFO csp+lda | 001-2014 | 6 | session_E: Score 0.771
# 2019-09-04 10:28:05 desktop-270 root[1026] INFO csp+lda | 001-2014 | 6 | session_T: Score 0.786
# 2019-09-04 10:28:12 desktop-270 root[1026] INFO csp+lda | 001-2014 | 7 | session_E: Score 0.966
# 2019-09-04 10:28:12 desktop-270 root[1026] INFO csp+lda | 001-2014 | 7 | session_T: Score 0.846
# 2019-09-04 10:28:20 desktop-270 root[1026] INFO csp+lda | 001-2014 | 8 | session_E: Score 0.998
# 2019-09-04 10:28:21 desktop-270 root[1026] INFO csp+lda | 001-2014 | 8 | session_T: Score 1.000
# 2019-09-04 10:28:28 desktop-270 root[1026] INFO csp+lda | 001-2014 | 9 | session_E: Score 0.964
# 2019-09-04 10:28:29 desktop-270 root[1026] INFO csp+lda | 001-2014 | 9 | session_T: Score 0.829

# %%
results.to_csv('./results/results_part2-1.csv')

# %% [markdown]
# ### Plotting results

# %% [markdown]
# We create a figure with the `seaborn` package comparing the classification score for each subject on each session. Note that the *subject* field from the results object is given in terms of integers, but seaborn accepts only strings for its labeling. This is why we create the field *subj*

# %%
results = pd.read_csv('')
fig, ax = plt.subplots(figsize=(8,7))
results["subj"] = results["subject"].apply(str)
sns.barplot(x="score", y="subj", hue='session', data=results, orient='h', palette='viridis', ax=ax)
#sns.catplot(kind='bar', x="score", y="subj", hue='session', data=results, orient='h', palette='viridis')
fig.show()
